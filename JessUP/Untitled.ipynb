# %%
import numpy as np

# %%
X = 2 * np.random.rand(100,1)
y = 4 +3 * X+np.random.randn(100,1)

# %%
# Out:
# array([[0.74824814],
#        [1.74560072],
#        [1.2861849 ],
#        [0.56984082],
#        [1.45774751],
#        [1.71380285],
#        [0.04483093],
#        [1.44403442],
#        [1.92327112],
#        [1.04509375],
#        [0.34103664],
#        [1.23451048],
#        [1.65920254],
#        [0.55108597],
#        [1.13348524],
#        [1.83218805],
#        [1.07168946],
#        [1.71409494],
#        [0.06311903],
#        [1.45073936],
#        [0.46744225],
#        [1.43901399],
#        [0.96581559],
#        [1.98589246],
#        [0.33435862],
#        [0.86660758],
#        [0.71234021],
#        [1.51917802],
#        [1.02501832],
#        [1.22685006],
#        [1.31715591],
#        [1.3839386 ],
#        [0.16838944],
#        [1.30900579],
#        [1.21984394],
#        [1.20990188],
#        [0.79825977],
#        [0.42257052],
#        [0.78813717],
#        [0.87721237],
#        [1.13160131],
#        [0.70857412],
#        [1.21950831],
# ...
