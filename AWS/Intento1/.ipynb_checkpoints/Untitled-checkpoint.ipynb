# %%
dir()
library(doParallel)
cl <- makePSOCKcluster(7)
registerDoParallel(cl)
# Out:
# [1] "code.R"                              "device_failure - copia.csv"
# [3] "device_failure.csv"                  "Predictive Modeling Work Sample.pdf"
# [5] "Untitled.ipynb"
# Loading required package: foreach
# Loading required package: iterators
# Loading required package: parallel

# %%
#install.packages('doParallel')

# %%
data.raw <- read.csv(file='device_failure.csv') # few records kernels function works fine 
sum(is.na(data.raw)) # not nulls thank you :D
sapply(data.raw, class)
require(lubridate) # easy handle datetimes
require(dplyr) # like SQL in R, and also load pipe operator 
require(ggplot2) # easy, fast  adn nice plots 
data.raw %>% arrange(device, date) %>% mutate(date = ymd(date) ) -> data.raw
names(data.raw)
#View(data.raw)
n.fails.index <- which(data.raw$failure==1)
nn.fails <- data.raw[ rep(n.fails.index, each=9) + -4:4, ]
#View(nn.fails)
data.raw %>% filter(failure==1) %>% group_by(device) %>% summarise(n=n()) -> t
summary(t$n)
data <- data.raw
table(data$failure) / dim(data)[1]
summary(data)
createPartition <- function(data, p=0.8){
  t <- unique(data$device)
  n <- length(t)
  n.p <- round(n*p, 0)
  t.sample <- sample(t, n.p)
  train.index <- which( data$device %in% t.sample)
  return(train.index)
}

ggplot(data, aes(date, attribute1, color= device, alpha=.03 )) + geom_line() +   theme_minimal() + 
  theme(legend.position="none") 
ggplot(data, aes(attribute1, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute2, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute3, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute4, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute5, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute6, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute7, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute8, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute9, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
index.columns <- c(2, 3, 4, 7, 8, 9) + 3
# Out:
# [1] 0
#       date     device    failure attribute1 attribute2 attribute3 attribute4
#   "factor"   "factor"  "integer"  "integer"  "integer"  "integer"  "integer"
# attribute5 attribute6 attribute7 attribute8 attribute9
#  "integer"  "integer"  "integer"  "integer"  "integer"
# Loading required package: lubridate
#
# Attaching package: ‘lubridate’
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: ggplot2
#  [1] "date"       "device"     "failure"    "attribute1" "attribute2"
#  [6] "attribute3" "attribute4" "attribute5" "attribute6" "attribute7"
# [11] "attribute8" "attribute9"
# `summarise()` ungrouping output (override with `.groups` argument)
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       1       1       1       1       1       1
#            0            1
# 0.9991485533 0.0008514467
#       date                 device          failure            attribute1
#  Min.   :2015-01-01   S1F0E9EP:   304   Min.   :0.0000000   Min.   :        0
#  1st Qu.:2015-02-09   S1F0EGMT:   304   1st Qu.:0.0000000   1st Qu.: 61284762
#  Median :2015-03-27   S1F0FGBQ:   304   Median :0.0000000   Median :122797388
#  Mean   :2015-04-16   S1F0FP0C:   304   Mean   :0.0008514   Mean   :122388103
#  3rd Qu.:2015-06-17   S1F0GCED:   304   3rd Qu.:0.0000000   3rd Qu.:183309640
#  Max.   :2015-11-02   S1F0GGPP:   304   Max.   :1.0000000   Max.   :244140480
#                       (Other) :122670
#    attribute2        attribute3         attribute4         attribute5
#  Min.   :    0.0   Min.   :    0.00   Min.   :   0.000   Min.   : 1.00
#  1st Qu.:    0.0   1st Qu.:    0.00   1st Qu.:   0.000   1st Qu.: 8.00
#  Median :    0.0   Median :    0.00   Median :   0.000   Median :10.00
#  Mean   :  159.5   Mean   :    9.94   Mean   :   1.741   Mean   :14.22
#  3rd Qu.:    0.0   3rd Qu.:    0.00   3rd Qu.:   0.000   3rd Qu.:12.00
#  Max.   :64968.0   Max.   :24929.00   Max.   :1666.000   Max.   :98.00
#
#    attribute6       attribute7         attribute8         attribute9
#  Min.   :     8   Min.   :  0.0000   Min.   :  0.0000   Min.   :    0.00
#  1st Qu.:221452   1st Qu.:  0.0000   1st Qu.:  0.0000   1st Qu.:    0.00
#  Median :249800   Median :  0.0000   Median :  0.0000   Median :    0.00
#  Mean   :260173   Mean   :  0.2925   Mean   :  0.2925   Mean   :   12.45
#  3rd Qu.:310266   3rd Qu.:  0.0000   3rd Qu.:  0.0000   3rd Qu.:    0.00
#  Max.   :689161   Max.   :832.0000   Max.   :832.0000   Max.   :18701.00
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# log features selected 
data[, names(data)[index.columns]] <-  log(data[, names(data)[index.columns]] + 1 )
# standar features 

index.columns <- grep('attr', names(data.raw))
summary(data)

for ( i in index.columns )
{
  temp <- data[, names(data)[i]]
  data[, names(data)[i]] <- scale(temp)
}
ggplot(data, aes(attribute1, fill =  as.character(failure), alpha=.01)) +
  geom_density() + theme_minimal()
ggplot(data, aes(attribute2, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute3, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute4, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute5, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute6, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute7, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute8, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
ggplot(data, aes(attribute9, fill =  as.character(failure), alpha=.01)) +
  geom_density()  + theme_minimal()
# Out:
#       date                 device          failure            attribute1
#  Min.   :2015-01-01   S1F0E9EP:   304   Min.   :0.0000000   Min.   :        0
#  1st Qu.:2015-02-09   S1F0EGMT:   304   1st Qu.:0.0000000   1st Qu.: 61284762
#  Median :2015-03-27   S1F0FGBQ:   304   Median :0.0000000   Median :122797388
#  Mean   :2015-04-16   S1F0FP0C:   304   Mean   :0.0008514   Mean   :122388103
#  3rd Qu.:2015-06-17   S1F0GCED:   304   3rd Qu.:0.0000000   3rd Qu.:183309640
#  Max.   :2015-11-02   S1F0GGPP:   304   Max.   :1.0000000   Max.   :244140480
#                       (Other) :122670
#    attribute2        attribute3        attribute4       attribute5
#  Min.   : 0.0000   Min.   : 0.0000   Min.   :0.0000   Min.   : 1.00
#  1st Qu.: 0.0000   1st Qu.: 0.0000   1st Qu.:0.0000   1st Qu.: 8.00
#  Median : 0.0000   Median : 0.0000   Median :0.0000   Median :10.00
#  Mean   : 0.3187   Mean   : 0.1778   Mean   :0.1631   Mean   :14.22
#  3rd Qu.: 0.0000   3rd Qu.: 0.0000   3rd Qu.:0.0000   3rd Qu.:12.00
#  Max.   :11.0817   Max.   :10.1238   Max.   :7.4188   Max.   :98.00
#
#    attribute6       attribute7        attribute8        attribute9
#  Min.   :     8   Min.   :0.00000   Min.   :0.00000   Min.   :0.0000
#  1st Qu.:221452   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.0000
#  Median :249800   Median :0.00000   Median :0.00000   Median :0.0000
#  Mean   :260173   Mean   :0.03156   Mean   :0.03156   Mean   :0.3959
#  3rd Qu.:310266   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.0000
#  Max.   :689161   Max.   :6.72503   Max.   :6.72503   Max.   :9.8364
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
############### Split data 
require(caret)
set.seed(0)
data$failure <- factor(data$failure)
levels(data$failure) <- c('NoFailure', 'Failure')
train.index <- createPartition(data)
data$date <- data$device <- NULL
train <- data[train.index, ]
test <- data[-train.index, ]
table(train$failure)/dim(train)[1]
####################   train
# Out:
# Loading required package: caret
# Loading required package: lattice
#    NoFailure      Failure
# 0.9991495479 0.0008504521

# %%
#install.packages('MLmetrics')
require(MLmetrics)
f1 <- function (data, lev = NULL, model = NULL) {
  precision <- posPredValue(data$pred, data$obs, positive = "Failure")
  recall  <- sensitivity(data$pred, data$obs, positive = "Failure")
  f1_val <- (2 * precision * recall) / (precision + recall)
  names(f1_val) <- c("F1")
  f1_val
}
# Out:
# Loading required package: MLmetrics
#
# Attaching package: ‘MLmetrics’
#
# The following objects are masked from ‘package:caret’:
#
#     MAE, RMSE
#
# The following object is masked from ‘package:base’:
#
#     Recall

# %%
fit.control <- trainControl( method = "cv", number = 5, repeats = 2,
                             allowParallel = TRUE, classProbs = TRUE,
                             summaryFunction = f1)
# Out:
# Warning message:
# “`repeats` has no meaning for this resampling method.”

# %%
require(gbm)
require(e1071) # svm impmelemntation 
require(kernlab) # kernels implementation
# Out:
# Loading required package: gbm
# Loaded gbm 2.1.8
# Loading required package: e1071
# Loading required package: kernlab
#
# Attaching package: ‘kernlab’
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha

# %%
#install.packages('gbm')

# %%
#install.packages('e1071')

# %%
#install.packages('kernlab')

# %%
gbmFit1 <- train(failure ~ ., data = train, method = "gbm", trControl = fit.control, metric = "Kappa", 
                 verbose = TRUE)
gbmFit1
# Out:
# Warning message in train.default(x, y, weights = w, ...):
# “The metric "Kappa" was not in the result set. F1 will be used instead.”Warning message in nominalTrainWorkflow(x = x, y = y, wts = weights, info = trainInfo, :
# “There were missing values in resampled performance measures.”
# Iter   TrainDeviance   ValidDeviance   StepSize   Improve
#      1        0.0262            -nan     0.1000   -0.0039
#      2           inf            -nan     0.1000      -inf
#      3           inf            -nan     0.1000      -nan
#      4           inf            -nan     0.1000      -nan
#      5           inf            -nan     0.1000      -nan
#      6           inf            -nan     0.1000      -nan
#      7           inf            -nan     0.1000      -nan
#      8           inf            -nan     0.1000      -nan
#      9           inf            -nan     0.1000      -nan
#     10           inf            -nan     0.1000      -nan
#     20           inf            -nan     0.1000      -nan
#     40           inf            -nan     0.1000      -nan
#     50           inf            -nan     0.1000      -nan
# Stochastic Gradient Boosting
#
# 98771 samples
#     9 predictor
#     2 classes: 'NoFailure', 'Failure'
#
# No pre-processing
# Resampling: Cross-Validated (5 fold)
# Summary of sample sizes: 79017, 79017, 79016, 79018, 79016
# Resampling results across tuning parameters:
#
#   interaction.depth  n.trees  F1
#   1                   50      0.08000000
#   1                  100      0.08000000
#   1                  150      0.09555556
#   2                   50      0.08998989
#   2                  100      0.08429459
#   2                  150      0.08429459
#   3                   50      0.14090909
#   3                  100      0.14090909
#   3                  150      0.13333333
#
# Tuning parameter 'shrinkage' was held constant at a value of 0.1
#
# Tuning parameter 'n.minobsinnode' was held constant at a value of 10
# F1 was used to select the optimal model using the largest value.
# The final values used for the model were n.trees = 50, interaction.depth =
#  3, shrinkage = 0.1 and n.minobsinnode = 10.

# %% [markdown]
# svm.polyFit1 <- train(failure ~ ., data = train, method = "svmRadial", trControl = fit.control,
#                  verbose = TRUE)
# svm.polyFit1

# %%
install.packages('ranger')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
gbmFit1

# %%
require(randomForest)
rf.Fit1 <- train(failure ~ ., data = train, method = "ranger", trControl = fit.control, metric = "Kappa", 
                 verbose = TRUE)
rf.Fit1
# Out:
# Loading required package: randomForest
# randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: ‘randomForest’
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# Warning message in train.default(x, y, weights = w, ...):
# “The metric "Kappa" was not in the result set. F1 will be used instead.”Warning message in nominalTrainWorkflow(x = x, y = y, wts = weights, info = trainInfo, :
# “There were missing values in resampled performance measures.”Warning message in train.default(x, y, weights = w, ...):
# “missing values found in aggregated results”
# Random Forest
#
# 98771 samples
#     9 predictor
#     2 classes: 'NoFailure', 'Failure'
#
# No pre-processing
# Resampling: Cross-Validated (5 fold)
# Summary of sample sizes: 79017, 79018, 79017, 79016, 79016
# Resampling results across tuning parameters:
#
#   mtry  splitrule   F1
#   2     gini               NaN
#   2     extratrees         NaN
#   5     gini               NaN
#   5     extratrees         NaN
#   9     gini        0.08333333
#   9     extratrees         NaN
#
# Tuning parameter 'min.node.size' was held constant at a value of 1
# F1 was used to select the optimal model using the largest value.
# The final values used for the model were mtry = 9, splitrule = gini
#  and min.node.size = 1.

# %%
rf.Fit1
# Out:
# Random Forest
#
# 98771 samples
#     9 predictor
#     2 classes: 'NoFailure', 'Failure'
#
# No pre-processing
# Resampling: Cross-Validated (5 fold)
# Summary of sample sizes: 79017, 79018, 79017, 79016, 79016
# Resampling results across tuning parameters:
#
#   mtry  splitrule   F1
#   2     gini               NaN
#   2     extratrees         NaN
#   5     gini               NaN
#   5     extratrees         NaN
#   9     gini        0.08333333
#   9     extratrees         NaN
#
# Tuning parameter 'min.node.size' was held constant at a value of 1
# F1 was used to select the optimal model using the largest value.
# The final values used for the model were mtry = 9, splitrule = gini
#  and min.node.size = 1.

# %%
#install.packages('LiblineaR')

# %%
rlg.Fit1 <-train(failure ~ ., data = train, method = "regLogistic", trControl = fit.control,metric = "Kappa", 
                 verbose = TRUE)
rlg.Fit1
# Out:
# Warning message in train.default(x, y, weights = w, ...):
# “The metric "Accuracy" was not in the result set. F1 will be used instead.”

# %%
rlg.Fit1

# %%
#resamps <- resamples(list(GBM = gbmFit1, RF = rf.Fit1))

resamps <- resamples(list(GBM = gbmFit1,
                          RF = rf.Fit1, RLG=rlg.Fit1  ))
resamps

# %%
summary(resamps)

# %%
theme1 <- trellis.par.get()
theme1$plot.symbol$col = rgb(.2, .2, .2, .4)
theme1$plot.symbol$pch = 16
theme1$plot.line$col = rgb(1, 0, 0, .7)
theme1$plot.line$lwd <- 2
trellis.par.set(theme1)
bwplot(resamps, layout = c(3, 1))

# %%
## When you are done:
stopCluster(cl)
